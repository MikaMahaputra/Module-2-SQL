# %% [markdown]
# <title> Python Basic Exercise #1 </title>

# %% [markdown]
# <img src="/logo_full.png" width="" align="" />

# %% [markdown]
# <br>
#
# ---
#
# <br>

# %% [markdown]
# # Pandas Basic Exercise #2

# %% [markdown]
# Total Question: 9 Task
# Topic: Series, DataFrame, Pandas Indexing, Pandas operation

# %%
import pandas as pd

# %% [markdown]
# ## Task 1 - Create a Series

# %% [markdown]
# Create a Pandas Series named "population" representing the population of five different cities: New York (8.5 million), Los Angeles (4 million), Chicago (2.7 million), Houston (2.3 million), and Phoenix (1.7 million)

# %%
data_dict = {"New York": 8_500_000, "Los Angeles": 4_000_000, "Chicago": 2_700_000, "Houston":2_300_000, "Phoenix":1_700_000}
ser = pd.Series(data_dict)
print(ser)
# Out:
# New York       8500000
# Los Angeles    4000000
# Chicago        2700000
# Houston        2300000
# Phoenix        1700000
# dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# ## Task 2 - Create a DataFrame

# %% [markdown]
# Create a Pandas DataFrame named "city_data" representing the same cities with their respective population, area (in square miles), and whether they are coastal cities (True/False). Use the following data:

# %% [markdown]
# - New York: 8.5 million, 469, True
# - Los Angeles: 4 million, 503, True
# - Chicago: 2.7 million, 234, False
# - Houston: 2.3 million, 599, True
# - Phoenix: 1.7 million, 517, False

# %%
city_data = [
    {"City": "New York",
     "Population": 8_500_000,
     "Area": 469,
     "Coastal": True,
     },
     {
     "City": "Los Angeles",
     "Population": 4_000_000,
     "Area": 503,
     "Coastal": True,
     },
    {
     "City": "Chicago",
     "Population": 2_700_000,
     "Area": 234,
     "Coastal": False,
     },
    {
     "City": "Houston",
     "Population": 2_300_000,
     "Area": 599,
     "Coastal": True,
     },
    {
     "City": "Phoenix",
     "Population": 1_700_000,
     "Area": 517,
     "Coastal": False
     }
]
df = pd.DataFrame(city_data)
df
# Out:
#           City  Population  Area  Coastal
# 0     New York     8500000   469     True
# 1  Los Angeles     4000000   503     True
# 2      Chicago     2700000   234    False
# 3      Houston     2300000   599     True
# 4      Phoenix     1700000   517    False

# %% [markdown]
# <br>

# %% [markdown]
# ## Task 3 -   Indexing Series

# %%
# Print the population of Chicago from the "population" Series.
# Print the populations of cities with indices 1 and 3 from the "population" Series.

# %% [markdown]
# <br>

# %% [markdown]
# ## Task 4 -  Conditional Filtering DataFrame

# %%
# Filter the "city_data" DataFrame to show only coastal cities.

# %%
# Filter the "city_data" DataFrame to show only cities with a population greater than 2 million.

# %%
# Filter the "city_data" DataFrame to show only cities with an area less than 300 square miles.

# %% [markdown]
# <br>

# %% [markdown]
# ## Task 5 - Operations on Series

# %% [markdown]
# - Create a Pandas Series named "temperature" representing the temperature in degrees Celsius for five consecutive days (e.g., 20, 22, 19, 25, 18).

# %% [markdown]
# - Convert the temperature from Celsius to Fahrenheit (F = (C * 9/5) + 32)

# %%
# Your code here

# %% [markdown]
# <br>

# %% [markdown]
# ## Task 6 - Operations on DataFrame

# %% [markdown]
# - Add a new column to the "city_data" DataFrame named "Population Density" calculated by dividing population by area.

# %% [markdown]
# - Add a new column to the "city_data" DataFrame named "Population Change" representing the percentage change in population from 2020 to 2024 for each city. Assume the population in 2020 was [8.4, 3.9, 2.8, 2.2, 1.6] million.

# %%
# Your code here

# %% [markdown]
# <br>

# %% [markdown]
# ## Task 7 - Data Manipulation

# %% [markdown]
# Rename the columns of the "city_data" DataFrame to "Population (millions)", "Area (sq. km)", and "Is Coastal"

# %%
# Your code here

# %% [markdown]
# <br>

# %% [markdown]
# ## Task 8 - Advanced Conditional Filtering

# %%
# Filter the "city_data" DataFrame to show cities
# with a population density greater than the median population density

# %%
# Filter the "city_data" DataFrame to show cities
# with a population between 2 and 3 million and an area greater than 400 square miles.

# %% [markdown]
# <br>

# %% [markdown]
# ## Task 9 - Selecting Data Based on Multiple Conditions

# %% [markdown]
# Create a new DataFrame named "large_cities" containing cities from "city_data" with a population greater than 4 million or an area greater than 500 square miles.

# %% [markdown]
# Select cities from "large_cities" where the population density is greater than 5000 people per square mile.

# %% [markdown]
# <br>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=520e70a9-b7fd-4903-be7f-b6533a9e0dcb' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
